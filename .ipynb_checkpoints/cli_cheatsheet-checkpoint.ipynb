# %% [markdown]
# # 🖥️ Miniconda PowerShell Prompt Cheatsheet (CLI Basics)
# ---
#
# ## 📁 Navigate to a Data Directory
# ```powershell
# cd c:\data
# ```
#
# ## 📁 Navigate to another Drive or Volumne (if available)
# ```powershell
# i:
# ```
#
# ## 📁 Navigate to your Home Directory
#
# cd ~
#
#
# ## 📂 List Files in the Current Directory
# ```powershell
# ls
# ```
#
# ## 📂 Clear Screen
# ```powershell
# cls
#
# or
#
# clear
# ```
#
# ## 📂 List Files in the Current Directory in a GUI
# ```powershell
# start .
# ```
#
# ## 🔍 Check Current Directory
# ```powershell
# pwd
# ```
#
# ---
#
# ## 📌 Navigation Commands
# | Command              | Description                                      |
# |----------------------|--------------------------------------------------|
# | `cd ..`              | Move up one directory level                      |
# | `cd .`               | Stay in the current directory                    |
# | `cd`                 | Go to the home directory                         |
# | `cd "d:\My Folder"`  | Navigate to a directory with spaces in the name  |
# | `ls`                 | Alias for `dir` (lists files and folders)        |
# | <cntrl><c>           | Keys to kill the server                          |
#
# > 💡 **Tip**: Always wrap paths with spaces in **double quotes**.
#
# ---
#
# ## 🐍 Conda Environment Commands
# | Command                                  | Description                          |
# |------------------------------------------|--------------------------------------|
# | `conda activate myenv`                   | Activate environment `myenv`         |
# | `conda deactivate`                       | Deactivate current environment       |
# | `conda env list`                         | List all environments                |
# | `conda create --name myenv python=3.11` | Create new environment with Python   |
# | `conda remove --name myenv --all`       | Delete environment `myenv`           |
